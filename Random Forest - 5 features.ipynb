# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pickle
import tensorflow as tf
import pandas as pd
import numpy as np
import glob

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout 
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Conv1D
from tensorflow.keras import regularizers, optimizers
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization, GlobalAveragePooling1D
from tensorflow.keras.models import load_model
from tensorflow.data import Dataset
from keras.callbacks import EarlyStopping
import keras

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
import os
cwd = os.getcwd() 
print(cwd)
# Out:
# /content

# %%
# # old code
# sound_data = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ML Pickle Jar/0001-1000_mfcc_EDA_data")
# sound_data.head(5)

# %%
df_list = []
for filename in glob.glob("/content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/*"):
  print("Processing " + filename)
  df = pd.read_pickle(filename)
  df_list.append(df)

all_data = pd.concat(df_list, axis=0)
all_data.count()
# Out:
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/1000-2000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/2000-3000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/3000-4000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/4000-5000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/5000-6000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/6000-7000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/0001-1000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/7000-8000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/8000-9000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/9000-10000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/30000-35000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/35000-36000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/73001-73465_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/10000-11000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/72001-73001_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/71001-72000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/46000-47000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/47000-48000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/48000-49000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/70001-71000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/49000-50000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/36000-37000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/67001-68000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/37000-38000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/38000-39000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/66001-67000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/39000-40000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/65001-66000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/40000-41000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/50000-51000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/41000-42000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/42000-43000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/64001-65000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/51000-52000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/43000-44000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/52000-53000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/53000-54000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/44000-45000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/11000-12000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/54000-55000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/12000-13000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/55000-56000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/13000-14000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/56000-57000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/14000-15000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/63001-64000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/57000-58000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/58000-59000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/59000-60000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/45000-46000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/62001-63000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/61001-62000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/15000-16000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/23000-30000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/16000-23000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/60001-61000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/69001-70000_mfcc_EDA_data
# Processing /content/drive/MyDrive/Colab Notebooks/Code for submission/ML Pickle Jar/68001-69000_mfcc_EDA_data
# filename              73465
# text                  73465
# up_votes              73465
# down_votes            73465
# age                   73465
# gender                73465
# accent                63163
# mean_RMSE             73465
# mean_spec_centroid    73465
# mfcc                  73465
# meanff                72999
# q1                    73465
# iqr                   73465
# chroma                73465
# mel                   73465
# dtype: int64

# %%
sound_data = all_data.copy()

# %%
sound_data = sound_data.drop(columns=['up_votes','down_votes','text','accent'])
sound_data.head()
# Out:
#                               filename  ...                                                mel
# 1000  cv-valid-train/sample-002750.mp3  ...  [0.0029826183, 0.0051411446, 0.008285743, 0.01...
# 1001  cv-valid-train/sample-002756.mp3  ...  [0.039002493, 0.20496942, 4.5200353, 11.305368...
# 1002  cv-valid-train/sample-002762.mp3  ...  [9.714776e-06, 5.468462e-06, 5.4659545e-06, 6....
# 1003  cv-valid-train/sample-002763.mp3  ...  [0.00011609932, 0.00013558251, 0.00068590173, ...
# 1004  cv-valid-train/sample-002765.mp3  ...  [0.0014744281, 0.0017879839, 0.02412793, 0.357...
#
# [5 rows x 11 columns]

# %%
sound_data.reset_index(drop=True, inplace=True)

# %%
sound_data.drop(sound_data[sound_data["gender"]=="other"].index, inplace=True)

# %%
sound_data.drop(columns=["filename"], inplace=True)

# %%
age_dict = {
    "teens": 0,
    "twenties": 1,
    "thirties": 2,
    "fourties": 3,
    "fifties": 4,
    "sixties": 5,
    "seventies": 6,
    "eighties": 7
}
gender_dict = {
    "male": 0,
    "female": 1
}

for i in range(sound_data.shape[0]):
  sound_data["age"].iloc[i] = age_dict[sound_data["age"].iloc[i]]
  sound_data["gender"].iloc[i] = gender_dict[sound_data["gender"].iloc[i]]

sound_data.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#   age  ...                                                mel
# 0   2  ...  [0.0029826183, 0.0051411446, 0.008285743, 0.01...
# 1   4  ...  [0.039002493, 0.20496942, 4.5200353, 11.305368...
# 2   2  ...  [9.714776e-06, 5.468462e-06, 5.4659545e-06, 6....
# 3   6  ...  [0.00011609932, 0.00013558251, 0.00068590173, ...
# 4   3  ...  [0.0014744281, 0.0017879839, 0.02412793, 0.357...
#
# [5 rows x 10 columns]

# %% [markdown]
# ### Gender

# %%
def get_np_means(arr):
  return np.mean(arr.T, axis=0)

# %%
gender_data = sound_data.copy()


# np.mean() mfccs
gender_data["mfcc"] = gender_data["mfcc"].apply(get_np_means)
gender_data = gender_data.dropna()
gender_data.head()
# Out:
#   age  ...                                                mel
# 0   2  ...  [0.0029826183, 0.0051411446, 0.008285743, 0.01...
# 1   4  ...  [0.039002493, 0.20496942, 4.5200353, 11.305368...
# 2   2  ...  [9.714776e-06, 5.468462e-06, 5.4659545e-06, 6....
# 3   6  ...  [0.00011609932, 0.00013558251, 0.00068590173, ...
# 4   3  ...  [0.0014744281, 0.0017879839, 0.02412793, 0.357...
#
# [5 rows x 10 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from matplotlib.legend_handler import HandlerLine2D

# %%
single_data_columns = ["mean_RMSE","mean_spec_centroid","meanff","q1","iqr"]

x = gender_data[single_data_columns]
y = gender_data['gender']

# %%
y=y.astype('int')

# %%
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler

oversampler = RandomOverSampler(random_state = 0)
os_x, os_y = oversampler.fit_sample(x, y)
x_train, x_test, y_train, y_test = train_test_split(os_x, os_y, test_size = 0.2, random_state = 0)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
# np.save("os_x", os_x)
# np.save("os_y", os_y)

# %%
ss = StandardScaler()
mm = MinMaxScaler()
x_train = ss.fit_transform(x_train)
x_test = ss.fit_transform(x_test)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

# %%
def RF_model(n_estimators = 100, max_depth=None, min_samples_leaf=1, 
             max_features='auto', max_leaf_nodes=None, min_samples_split=2, random_state=0):
  
  rf_model = RandomForestClassifier(n_estimators = n_estimators, max_depth=max_depth, 
                                    min_samples_leaf=min_samples_leaf, max_features=max_features, 
                                    max_leaf_nodes=max_leaf_nodes, min_samples_split=min_samples_split, random_state=0)
  rf_model.fit(x_train, y_train)
  y_train_pred = rf_model.predict(x_train)
  y_test_pred = rf_model.predict(x_test)

  return y_train_pred, y_test_pred


def print_report(y_train_pred, y_test_pred, target_names = ['class 0 - male', 'class 1 - female']):

  classification_report_train = classification_report(y_train, y_train_pred, target_names=target_names)
  accuracy_train = accuracy_score(y_train_pred, y_train)

  classification_report_test = classification_report(y_test, y_test_pred, target_names=target_names)
  accuracy_test = accuracy_score(y_test_pred, y_test)

  print("-" * 50)
  print("TRAIN")
  print("-" * 50)
  print("classification report: ")
  print(classification_report_train)
  print("accuracy score: " + str(accuracy_train))
  print("-" * 50)
  print("TEST")
  print("-" * 50)
  print("classification report: ") 
  print(classification_report_test)
  print("accuracy score: " + str(accuracy_test))

# %% [markdown]
# Default Model from SKLearn

# %%
 y_train_pred, y_test_pred = RF_model()
 print_report(y_train_pred, y_test_pred)
# Out:
# --------------------------------------------------
# TRAIN
# --------------------------------------------------
# classification report:
#                   precision    recall  f1-score   support
#
#   class 0 - male       1.00      1.00      1.00     43396
# class 1 - female       1.00      1.00      1.00     43240
#
#         accuracy                           1.00     86636
#        macro avg       1.00      1.00      1.00     86636
#     weighted avg       1.00      1.00      1.00     86636
#
# accuracy score: 0.9999769149083522
# --------------------------------------------------
# TEST
# --------------------------------------------------
# classification report:
#                   precision    recall  f1-score   support
#
#   class 0 - male       0.92      0.91      0.91     10752
# class 1 - female       0.91      0.92      0.92     10908
#
#         accuracy                           0.92     21660
#        macro avg       0.92      0.92      0.92     21660
#     weighted avg       0.92      0.92      0.92     21660
#
# accuracy score: 0.9156048014773777

# %% [markdown]
# Best n estimators

# %%
train_results = []
test_results = []
n_estimators = [4, 8, 16, 32, 64, 128, 256]
best_estimator, acc = 0,0

for estimator in n_estimators:
    y_train_pred, y_test_pred = RF_model(n_estimators=estimator)

    accuracy_train = accuracy_score(y_train_pred, y_train)
    train_results.append(accuracy_train)

    accuracy_test = accuracy_score(y_test_pred, y_test)
    test_results.append(accuracy_test)

    if accuracy_test > acc:
      best_estimator, acc = estimator, accuracy_test


line1, = plt.plot(n_estimators, train_results, 'b', label = 'Train Accuracy')
line2, = plt.plot(n_estimators, test_results, 'r', label = 'Test Accuracy')
plt.legend(handler_map = {line1: HandlerLine2D(numpoints = 2)})
plt.ylabel('Accuracy')
plt.xlabel('n_estimators')
plt.show()

# %% [markdown]
# Different Max Features

# %%
train_results = []
test_results = []
max_features = ['auto','sqrt','log2']
best_feature, acc = 0,0

for feature in max_features:
    y_train_pred, y_test_pred = RF_model(max_features=feature)

    accuracy_train = accuracy_score(y_train_pred, y_train)
    train_results.append(accuracy_train)

    accuracy_test = accuracy_score(y_test_pred, y_test)
    test_results.append(accuracy_test)

    if accuracy_test > acc:
      best_feature, acc = feature, accuracy_test

line1, = plt.plot(max_features, train_results, 'b', label = 'Train Accuracy')
line2, = plt.plot(max_features, test_results, 'r', label = 'Test Accuracy')
plt.legend(handler_map = {line1: HandlerLine2D(numpoints = 2)})
plt.ylabel('Accuracy')
plt.xlabel('max_features')
plt.show()

# %% [markdown]
# Different Min leafs

# %%
train_results = []
test_results = []
min_samples_leaf = [1,2,4,8,16,32,48,64,128]
best_leaf, acc = 0,0

for leaf in min_samples_leaf:
    y_train_pred, y_test_pred = RF_model(min_samples_leaf = leaf)

    accuracy_train = accuracy_score(y_train_pred, y_train)
    train_results.append(accuracy_train)

    accuracy_test = accuracy_score(y_test_pred, y_test)
    test_results.append(accuracy_test)

    if accuracy_test > acc:
      best_leaf, acc = leaf, accuracy_test

line1, = plt.plot(min_samples_leaf, train_results, 'b', label = 'Train Accuracy')
line2, = plt.plot(min_samples_leaf, test_results, 'r', label = 'Test Accuracy')
plt.legend(handler_map = {line1: HandlerLine2D(numpoints = 2)})
plt.ylabel('Accuracy')
plt.xlabel('min_samples_leaf')
plt.show()

# %% [markdown]
# Different Max Depth

# %%
train_results = []
test_results = []
max_depth = [1, 2, 3, 5, 7, 10, 15, 20]
best_depth, acc = 0,0

for depth in max_depth:
    y_train_pred, y_test_pred = RF_model(max_depth = depth)

    accuracy_train = accuracy_score(y_train_pred, y_train)
    train_results.append(accuracy_train)

    accuracy_test = accuracy_score(y_test_pred, y_test)
    test_results.append(accuracy_test)

    if accuracy_test > acc:
        best_depth, acc = depth, accuracy_test


line1, = plt.plot(max_depth, train_results, 'b', label = 'Train Accuracy')
line2, = plt.plot(max_depth, test_results, 'r', label = 'Test Accuracy')
plt.legend(handler_map = {line1: HandlerLine2D(numpoints = 2)})
plt.ylabel('Accuracy')
plt.xlabel('max_depth')
plt.show()

# %% [markdown]
# Different max_leaf_nodes

# %%
train_results = []
test_results = []
max_leaf_nodes = [2, 4, 8, 16, 32, 64, 128]
best_max_leaf, acc = 0,0

for max_leaf in max_leaf_nodes:
    y_train_pred, y_test_pred = RF_model(max_leaf_nodes = max_leaf)

    accuracy_train = accuracy_score(y_train_pred, y_train)
    train_results.append(accuracy_train)

    accuracy_test = accuracy_score(y_test_pred, y_test)
    test_results.append(accuracy_test)

    if accuracy_test > acc:
        best_max_leaf, acc = max_leaf, accuracy_test


line1, = plt.plot(max_leaf_nodes, train_results, 'b', label = 'Train Accuracy')
line2, = plt.plot(max_leaf_nodes, test_results, 'r', label = 'Test Accuracy')
plt.legend(handler_map = {line1: HandlerLine2D(numpoints = 2)})
plt.ylabel('Accuracy')
plt.xlabel('max_leaf_nodes')
plt.show()

# %% [markdown]
# Different min_samples_split

# %%
train_results = []
test_results = []
min_samples_split = [2, 4, 8, 16, 32, 64, 128]
best_min_sample, acc = 0,0

for min_sample in min_samples_split:
    y_train_pred, y_test_pred = RF_model(min_samples_split = min_sample)

    accuracy_train = accuracy_score(y_train_pred, y_train)
    train_results.append(accuracy_train)

    accuracy_test = accuracy_score(y_test_pred, y_test)
    test_results.append(accuracy_test)

    if accuracy_test > acc:
        best_min_sample, acc = min_sample, accuracy_test


line1, = plt.plot(min_samples_split, train_results, 'b', label = 'Train Accuracy')
line2, = plt.plot(min_samples_split, test_results, 'r', label = 'Test Accuracy')
plt.legend(handler_map = {line1: HandlerLine2D(numpoints = 2)})
plt.ylabel('Accuracy')
plt.xlabel('min_samples_split')
plt.show()

# %% [markdown]
# BEST Model

# %%
 y_train_pred, y_test_pred = RF_model(min_samples_split = best_min_sample, max_leaf_nodes = best_max_leaf, max_depth = best_depth,
                                      min_samples_leaf = best_leaf, max_features = best_feature, n_estimators = best_estimator)
 print_report(y_train_pred, y_test_pred)
# Out:
# --------------------------------------------------
# TRAIN
# --------------------------------------------------
# classification report:
#                   precision    recall  f1-score   support
#
#   class 0 - male       0.92      0.88      0.90     43396
# class 1 - female       0.89      0.92      0.90     43240
#
#         accuracy                           0.90     86636
#        macro avg       0.90      0.90      0.90     86636
#     weighted avg       0.90      0.90      0.90     86636
#
# accuracy score: 0.902280807054804
# --------------------------------------------------
# TEST
# --------------------------------------------------
# classification report:
#                   precision    recall  f1-score   support
#
#   class 0 - male       0.90      0.87      0.89     10752
# class 1 - female       0.88      0.91      0.89     10908
#
#         accuracy                           0.89     21660
#        macro avg       0.89      0.89      0.89     21660
#     weighted avg       0.89      0.89      0.89     21660
#
# accuracy score: 0.8907663896583564

# %%
print(f"best_min_sample_split is 2")
print(f"best_max_leaf_node is None")
print(f"best_max_depth is None")
print(f"best_min_sample_leaf is 1")
print(f"best_max_feature is auto")
print(f"best_estimator is 100")
# Out:
# best_min_sample_split is 2
# best_max_leaf_node is None
# best_max_depth is None
# best_min_sample_leaf is 1
# best_max_feature is auto
# best_estimator is 100

# %%
#plot confusion matrix

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

cm = pd.DataFrame(confusion_matrix(y_test,y_test_pred) , index = ['Male', 'Female'] , columns = ['Male', 'Female'])
sns.heatmap(cm,cmap= 'Blues', annot = True, fmt='', xticklabels = ['Male', 'Female'], yticklabels = ['Male', 'Female'])
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title('Confusion matrix on test data')
plt.show()

# %% [markdown]
# # AGE

# %%
def get_np_means(arr):
  return np.mean(arr.T, axis=0)

# %%
age_data = sound_data.copy()

# np.mean() mfccs
age_data["mfcc"] = age_data["mfcc"].apply(get_np_means)
age_data = age_data.dropna()
age_data.head()
# Out:
#   age  ...                                                mel
# 0   2  ...  [0.0029826183, 0.0051411446, 0.008285743, 0.01...
# 1   4  ...  [0.039002493, 0.20496942, 4.5200353, 11.305368...
# 2   2  ...  [9.714776e-06, 5.468462e-06, 5.4659545e-06, 6....
# 3   6  ...  [0.00011609932, 0.00013558251, 0.00068590173, ...
# 4   3  ...  [0.0014744281, 0.0017879839, 0.02412793, 0.357...
#
# [5 rows x 10 columns]

# %%
age_data['age'].value_counts()
# Out:
# 1    22331
# 2    18082
# 3    10787
# 4     9388
# 0     5257
# 5     4543
# 6     1601
# 7      239
# Name: age, dtype: int64

# %%
age_data.drop(age_data[age_data.age == 6].index, inplace=True)
age_data.drop(age_data[age_data.age == 7].index, inplace=True)

# %%
y = age_data['age']
y=y.astype('int')

# %%
single_data_columns = ["mean_RMSE","mean_spec_centroid","meanff","q1","iqr"]

x = age_data[single_data_columns]

# %%
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler

oversampler = RandomOverSampler(random_state = 0)
os_x, os_y = oversampler.fit_sample(x, y)
x_train, x_test, y_train, y_test = train_test_split(os_x, os_y, test_size = 0.2, random_state = 0)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
ss = StandardScaler()
mm = MinMaxScaler()
x_train = ss.fit_transform(x_train)
x_test = ss.fit_transform(x_test)

# %% [markdown]
# Default Model

# %%
 y_train_pred, y_test_pred = RF_model()
 print_report(y_train_pred, y_test_pred, target_names=None)
# Out:
# --------------------------------------------------
# TRAIN
# --------------------------------------------------
# classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     17949
#            1       1.00      1.00      1.00     17925
#            2       1.00      1.00      1.00     17777
#            3       1.00      1.00      1.00     17844
#            4       1.00      1.00      1.00     17887
#            5       1.00      1.00      1.00     17806
#
#     accuracy                           1.00    107188
#    macro avg       1.00      1.00      1.00    107188
# weighted avg       1.00      1.00      1.00    107188
#
# accuracy score: 1.0
# --------------------------------------------------
# TEST
# --------------------------------------------------
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.79      4382
#            1       0.42      0.45      0.44      4406
#            2       0.51      0.51      0.51      4554
#            3       0.66      0.69      0.68      4487
#            4       0.72      0.72      0.72      4444
#            5       0.85      0.80      0.82      4525
#
#     accuracy                           0.66     26798
#    macro avg       0.66      0.66      0.66     26798
# weighted avg       0.66      0.66      0.66     26798
#
# accuracy score: 0.657138592432271

# %% [markdown]
# Best n estimators

# %%
train_results = []
test_results = []
n_estimators = [4, 8, 16, 32, 64, 128, 256]
best_estimator, acc = 0,0

for estimator in n_estimators:
    y_train_pred, y_test_pred = RF_model(n_estimators=estimator)

    accuracy_train = accuracy_score(y_train_pred, y_train)
    train_results.append(accuracy_train)

    accuracy_test = accuracy_score(y_test_pred, y_test)
    test_results.append(accuracy_test)
    print (accuracy_test)

    if accuracy_test > acc:
      best_estimator, acc = estimator, accuracy_test


line1, = plt.plot(n_estimators, train_results, 'b', label = 'Train Accuracy')
line2, = plt.plot(n_estimators, test_results, 'r', label = 'Test Accuracy')
plt.legend(handler_map = {line1: HandlerLine2D(numpoints = 2)})
plt.ylabel('Accuracy')
plt.xlabel('n_estimators')
plt.show()
# Out:
# 0.4966042241958355
# 0.5565340697066945
# 0.6072094932457646
# 0.6319128293156205
# 0.6483692812896484
# 0.6573998059556684
# 0.6605716844540638

# %% [markdown]
# Different Max Features

# %%
train_results = []
test_results = []
max_features = ['auto','sqrt','log2']
best_feature, acc = 0,0

for feature in max_features:
    y_train_pred, y_test_pred = RF_model(max_features=feature)

    accuracy_train = accuracy_score(y_train_pred, y_train)
    train_results.append(accuracy_train)

    accuracy_test = accuracy_score(y_test_pred, y_test)
    test_results.append(accuracy_test)

    if accuracy_test > acc:
      best_feature, acc = feature, accuracy_test

line1, = plt.plot(max_features, train_results, 'b', label = 'Train Accuracy')
line2, = plt.plot(max_features, test_results, 'r', label = 'Test Accuracy')
plt.legend(handler_map = {line1: HandlerLine2D(numpoints = 2)})
plt.ylabel('Accuracy')
plt.xlabel('max_features')
plt.show()

# %% [markdown]
# Different Min leafs

# %%
train_results = []
test_results = []
min_samples_leaf = [1,2,4,8,16,32]
best_leaf, acc = 0,0

for leaf in min_samples_leaf:
    y_train_pred, y_test_pred = RF_model(min_samples_leaf = leaf)

    accuracy_train = accuracy_score(y_train_pred, y_train)
    train_results.append(accuracy_train)

    accuracy_test = accuracy_score(y_test_pred, y_test)
    test_results.append(accuracy_test)

    if accuracy_test > acc:
      best_leaf, acc = leaf, accuracy_test

line1, = plt.plot(min_samples_leaf, train_results, 'b', label = 'Train Accuracy')
line2, = plt.plot(min_samples_leaf, test_results, 'r', label = 'Test Accuracy')
plt.legend(handler_map = {line1: HandlerLine2D(numpoints = 2)})
plt.ylabel('Accuracy')
plt.xlabel('min_samples_leaf')
plt.show()

# %% [markdown]
# Different Max Depth

# %%
train_results = []
test_results = []
max_depth = [1, 2, 3, 5, 7, 10, 15]
best_depth, acc = 0,0

for depth in max_depth:
    y_train_pred, y_test_pred = RF_model(max_depth = depth)

    accuracy_train = accuracy_score(y_train_pred, y_train)
    train_results.append(accuracy_train)

    accuracy_test = accuracy_score(y_test_pred, y_test)
    test_results.append(accuracy_test)

    if accuracy_test > acc:
        best_depth, acc = depth, accuracy_test


line1, = plt.plot(max_depth, train_results, 'b', label = 'Train Accuracy')
line2, = plt.plot(max_depth, test_results, 'r', label = 'Test Accuracy')
plt.legend(handler_map = {line1: HandlerLine2D(numpoints = 2)})
plt.ylabel('Accuracy')
plt.xlabel('max_depth')
plt.show()

# %% [markdown]
# Different max_leaf_nodes

# %%
train_results = []
test_results = []
max_leaf_nodes = [2, 4, 8, 16, 32, 64, None]
best_max_leaf, acc = 0,0

for max_leaf in max_leaf_nodes:
    y_train_pred, y_test_pred = RF_model(max_leaf_nodes = max_leaf)

    accuracy_train = accuracy_score(y_train_pred, y_train)
    train_results.append(accuracy_train)

    accuracy_test = accuracy_score(y_test_pred, y_test)
    test_results.append(accuracy_test)

    if accuracy_test > acc:
        best_max_leaf, acc = max_leaf, accuracy_test


line1, = plt.plot(max_leaf_nodes, train_results, 'b', label = 'Train Accuracy')
line2, = plt.plot(max_leaf_nodes, test_results, 'r', label = 'Test Accuracy')
plt.legend(handler_map = {line1: HandlerLine2D(numpoints = 2)})
plt.ylabel('Accuracy')
plt.xlabel('max_leaf_nodes')
plt.show()

# %% [markdown]
# Different min_samples_split

# %%
train_results = []
test_results = []
min_samples_split = [2, 4, 8, 16, 32, 64]
best_min_sample, acc = 0,0

for min_sample in min_samples_split:
    y_train_pred, y_test_pred = RF_model(min_samples_split = min_sample)

    accuracy_train = accuracy_score(y_train_pred, y_train)
    train_results.append(accuracy_train)

    accuracy_test = accuracy_score(y_test_pred, y_test)
    test_results.append(accuracy_test)

    if accuracy_test > acc:
        best_min_sample, acc = min_sample, accuracy_test


line1, = plt.plot(min_samples_split, train_results, 'b', label = 'Train Accuracy')
line2, = plt.plot(min_samples_split, test_results, 'r', label = 'Test Accuracy')
plt.legend(handler_map = {line1: HandlerLine2D(numpoints = 2)})
plt.ylabel('Accuracy')
plt.xlabel('min_samples_split')
plt.show()

# %% [markdown]
# BEST Model

# %%
 y_train_pred, y_test_pred = RF_model(min_samples_split = best_min_sample, max_leaf_nodes = best_max_leaf, max_depth = best_depth,
                                      min_samples_leaf = best_leaf, max_features = best_feature, n_estimators = best_estimator)

print_report(y_train_pred, y_test_pred, target_names=None)
# Out:
# --------------------------------------------------
# TRAIN
# --------------------------------------------------
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87     17949
#            1       0.75      0.67      0.71     17925
#            2       0.70      0.72      0.71     17777
#            3       0.86      0.76      0.80     17844
#            4       0.80      0.81      0.80     17887
#            5       0.77      0.91      0.84     17806
#
#     accuracy                           0.79    107188
#    macro avg       0.79      0.79      0.79    107188
# weighted avg       0.79      0.79      0.79    107188
#
# accuracy score: 0.7893794081427026
# --------------------------------------------------
# TEST
# --------------------------------------------------
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.61      0.57      0.59      4382
#            1       0.34      0.34      0.34      4406
#            2       0.38      0.41      0.40      4554
#            3       0.52      0.45      0.49      4487
#            4       0.52      0.51      0.51      4444
#            5       0.59      0.67      0.63      4525
#
#     accuracy                           0.49     26798
#    macro avg       0.49      0.49      0.49     26798
# weighted avg       0.49      0.49      0.49     26798
#
# accuracy score: 0.491977013209941

# %%
print(f"best_min_sample_split is {best_min_sample}")
print(f"best_max_leaf_node is {best_max_leaf}")
print(f"best_max_depth is {best_depth}")
print(f"best_min_sample_leaf is {best_leaf}")
print(f"best_max_feature is {best_feature}")
print(f"best_estimator is {best_estimator}")
# Out:
# best_min_sample_split is 2
# best_max_leaf_node is None
# best_max_depth is 15
# best_min_sample_leaf is 1
# best_max_feature is auto
# best_estimator is 256

# %%
#plot confusion matrix for age

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

cm = pd.DataFrame(confusion_matrix(y_test,y_test_pred) , index = ['teens','twenties','thirties','fourties','fifties','sixties'] , columns = ['teens','twenties','thirties','fourties','fifties','sixties'])
sns.heatmap(cm,cmap= 'Blues', annot = True, fmt='', xticklabels = ['teens','twenties','thirties','fourties','fifties','sixties'], yticklabels = ['teens','twenties','thirties','fourties','fifties','sixties'])
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title('Confusion matrix on test data')
plt.show()
